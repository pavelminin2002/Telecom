# %%
import os

# %pip install wget
if not os.path.exists('thinkdsp.py'):
    # !python -m wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

import numpy as np
PI2 = np.pi * 2

import matplotlib.pyplot as plt

from thinkdsp import decorate
from thinkdsp import UncorrelatedGaussianNoise
# Out:
# Requirement already satisfied: wget in c:\users\pavel\anaconda3\lib\site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.
#
# Saved under thinkdsp.py

# %% [markdown]
# ## Упражнение 6.1
# В этой главе утверждается, что analyze1 требует времени пропорционально n^3, а analyze2 — пропорционально n^2. Убедитесь в этом, запуская их с несколькими разными массивами и засекая время работы. В блокнотах Jupyter можно использовать «волшебную команду» %timeit.
#
# Если печатать зависимость времени работы от размера на логарифмической шкале, то получится прямая линия с уклоном 3 для analyze1 и с уклоном 2 для analyze2.
#
# Также стоит поупражняться с dct_iv и scipy.fftpack.dct.

# %%
def analyze1(ys, fs, ts):
    args = np.outer(ts, fs)
    M = np.cos(PI2 * args)
    amps = np.linalg.solve(M, ys)
    return amps

def analyze2(ys, fs, ts):
    args = np.outer(ts, fs)
    M = np.cos(PI2 * args)
    amps = M.dot(ys) / 2
    return amps

def dct_iv(ys):
    N = len(ys)
    ts = (0.5 + np.arange(N)) / N
    fs = (0.5 + np.arange(N)) / 2
    args = np.outer(ts, fs)
    M = np.cos(PI2 * args)
    amps = np.dot(M, ys) / 2
    return amps

signal = UncorrelatedGaussianNoise()
wave = signal.make_wave(duration=1.0, framerate=16384)
wave.ys.shape
# Out:
# (16384,)

# %% [markdown]
# Возьмём размеры массива как степени тройки.

# %%
ns = 3 ** np.arange(3,9)
ns
# Out:
# array([  27,   81,  243,  729, 2187, 6561], dtype=int32)

# %% [markdown]
# Теперь посмотрим зависимость времени от размера матрицы, должна быть кубическая зависимость

# %%
best_analyze1 = []
for n in ns:
    ts = (0.5 + np.arange(n)) / n
    freqs = (0.5 + np.arange(n)) / 2
    ys = wave.ys[:n]
    best =  %timeit -r1 -o analyze1(ys,freqs,ts)
    best_analyze1.append(best.best)
best_analyze1
# Out:
# 40.1 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 10,000 loops each)
# 158 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 10,000 loops each)
# 1.27 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1,000 loops each)
# 16.6 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 10 loops each)
# 238 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# 5.08 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [4.0132890001405034e-05,
#  0.00015767702999874017,
#  0.0012704031000030226,
#  0.016638720000628382,
#  0.23777210002299398,
#  5.077259699988645]

# %%
best_analyze2 = []
for n in ns:
    ts = (0.5 + np.arange(n)) / n
    freqs = (0.5 + np.arange(n)) / 2
    ys = wave.ys[:n]
    best =  %timeit -r1 -o analyze2(ys,freqs,ts)
    best_analyze2.append(best.best)
best_analyze2
# Out:
# 20.9 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 10,000 loops each)
# 86.4 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 10,000 loops each)
# 618 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1,000 loops each)
# 8.2 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 100 loops each)
# 70.8 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 10 loops each)
# 605 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
# [2.0929219998652114e-05,
#  8.63778300001286e-05,
#  0.000618119699996896,
#  0.008200598999974319,
#  0.07077301000244915,
#  0.6054231000016443]

# %%
import scipy.fftpack

best_dct = []
for n in ns:
    ys = wave.ys[:n]
    best =  %timeit -r1 -o scipy.fftpack.dct(ys, type=3)
    best_dct.append(best.best)
best_dct
# Out:
# 9.41 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 100,000 loops each)
# 9.37 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 100,000 loops each)
# 10.8 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 100,000 loops each)
# 13.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 100,000 loops each)
# 26.7 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 10,000 loops each)
# 71.1 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 10,000 loops each)
# [9.40700499981176e-06,
#  9.366335000377148e-06,
#  1.0814085000311025e-05,
#  1.3686436000280082e-05,
#  2.6717399997869505e-05,
#  7.1116120001534e-05]

# %%
plt.plot(ns, best_analyze1, label='analyze1')
plt.plot(ns, best_analyze2, label='analyze2')
plt.plot(ns, best_dct, label='fftpack.dct')
loglog = dict(xscale='log', yscale='log')
decorate(xlabel='Wave length (N)', ylabel='Time (s)', **loglog)

# %%
from scipy.stats import linregress

linregress(np.log(ns),np.log(best_analyze1))
# Out:
# LinregressResult(slope=2.1655471742307433, intercept=-17.99409719318301, rvalue=0.9928388001039669, pvalue=7.674055279286881e-05, stderr=0.1302830435488255, intercept_stderr=0.824296130561597)

# %%
linregress(np.log(ns),np.log(best_analyze2))
# Out:
# LinregressResult(slope=1.9264164897461424, intercept=-17.552387491727927, rvalue=0.9970997941700429, pvalue=1.2604593687446453e-05, stderr=0.07351836818337767, intercept_stderr=0.4651480712150385)

# %%
linregress(np.log(ns),np.log(best_dct))
# Out:
# LinregressResult(slope=0.35094747612095095, intercept=-13.098487496753844, rvalue=0.9003030623816519, pvalue=0.014413751228336541, stderr=0.08483513273744969, intercept_stderr=0.5367488335114938)

# %% [markdown]
# Получили что, метод analyze1 пропорционален квадрату а не кубу.

# %% [markdown]
# ## Упражнение 6.2
# Одно из основных применений ДКП - это сжатие звука и изображений. В простейшей форме ДКП при сжатии работает следующим образом: <br>
# 1. Разбивает длинный сигнал на сегменты.
# 2. Вычисляет ДКП каждого сегмента.
# 3. Определяет частотные компоненты с такой амплитудой, что их не слышно, и удаляет их, сохраняя только оставшиеся частоты и амплитуды.
# 4. При воспроизведении сигнала загружает частоты и амплитуды каждого сегмента и применяет обратное ДКП.
#
# Реализуйте версию этого алгоритма и примените его для записи музыки или речи. Сколько компонент можно удалить до того, как разница станет заметной?
#
# Для того, чтобы этот метод стал практичным, нужен способ хранения прореженного массива, то есть массива, где большинство элементов равно нулю. NumPy (SciPy)дает несколько способов работы с прореженными массивами; о них можно прочитать на веб-странице [http://docs.scipy.org/doc/scipy/reference/sparse.html](http://docs.scipy.org/doc/scipy/reference/sparse.html)

# %%
from thinkdsp import read_wave

if not os.path.exists('electric-guitar-phrase.wav'):
    # !python -m wget https://github.com/pavelminin2002/Telecom/tree/main/Lab6/electric-guitar-phrase.wav

wave = read_wave('electric-guitar-phrase.wav')
wave.plot()
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Возьмем сегмент для сжатия

# %%
segment = wave.segment(start = 3.25,duration = 1.0)
segment.normalize()
segment.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Используем DFT

# %%
dct = segment.make_dct()
dct.plot(high = 5000)

# %%
def filtering(dct,limit = 0):
    for i, amp in enumerate(dct.amps):
        if np.abs(amp) < limit:
              dct.hs[i] = 0

# %%
filtering(dct,1000)

# %%
dct.plot(high = 5000)

# %%
dct = segment.make_dct()
filtering(dct,150)

# %% [markdown]
# Можно играться со значением лимита, чтобы подобрать запись более похожую на оригинал

# %%
dct.plot(high = 5000)
dct.make_wave().make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Получили сжатую запись

# %% [markdown]
# ## Упражнение 6.3
# В репозитории этой книги есть блокнот Jupyter под названием phase.ipnyb, в котором исследуется влияние фазы на восприятие звука. Прочтите этот блокнот и «погоняйте» примеры. Выберите иной сегмент звука и повторите эксперименты. Можно ли найти некие общие соотношения в фазовой структуре звука и его восприятии?

# %%
from thinkdsp import SawtoothSignal

signal = SawtoothSignal(freq=250, offset=0)
wave = signal.make_wave(duration=0.5, framerate=40000)
wave.segment(start=0.2,duration=0.01).plot()
decorate(xlabel='Time (s)')
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
decorate(xlabel='Frequency (Hz)',
         ylabel='Amplitude')

# %%
def plot_angle(spectrum, thresh=1):
    angles = spectrum.angles
    angles[spectrum.amps < thresh] = np.nan
    plt.plot(spectrum.fs, angles, 'x')
    decorate(xlabel='Frequency (Hz)', 
             ylabel='Phase (radian)')

# %%
plot_angle(spectrum, thresh=0)

# %%
plot_angle(spectrum, thresh=1)

# %%
def plot_three(spectrum, thresh=1):
    """Plot amplitude, phase, and waveform.

    spectrum: Spectrum object
    thresh: threshold passed to plot_angle
    """
    plt.figure(figsize=(10, 4))
    plt.subplot(1,3,1)
    spectrum.plot()
    plt.subplot(1,3,2)
    plot_angle(spectrum, thresh=thresh)
    plt.subplot(1,3,3)
    wave = spectrum.make_wave()
    wave.unbias()
    wave.normalize()
    wave.segment(duration=0.01).plot()
    display(wave.make_audio())

# %%
plot_three(spectrum)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Теперь меняем сигнал:

# %%
def rotate_angle(spectrum, offset):
    res = spectrum.copy()
    res.hs *= np.exp(1j * offset)
    return res

# %%
spectrum2 = rotate_angle(spectrum, 1)
plot_three(spectrum2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def zero_angle(spectrum):
    res = spectrum.copy()
    res.hs = res.amps
    return res

# %%
spectrum3 = zero_angle(spectrum2)
plot_three(spectrum3)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Сигнал не меняется

# %%
PI2 = np.pi * 2

def random_angle(spectrum):
    res = spectrum.copy()
    angles = np.random.uniform(0, PI2, len(spectrum))
    res.hs *= np.exp(1j * angles)
    return res

# %%
spectrum4 = random_angle(spectrum2)
plot_three(spectrum4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Звук стал более "электронным".
#
# Для звуков с простой гармонической структурой мы не слышим измнения в фазовой структуре, при условии что гармоническая структура неизменна.
